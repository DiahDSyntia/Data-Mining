# %% [markdown]
# There is a lot more that you can do with outputs (such as including interactive outputs)
# with your book. For more information about this, see [the Jupyter Book documentation](https://jupyterbook.org)

# %% [markdown]
# # Tugas 1

# %% [markdown]
# Tugas Menugukur Jarak (dissimiliarity) menggunakan python
# 1. ambil data dari keggle/github
# 2. ukur jarak
#
# d(1,2), d(1,2) d(1,4) objek dari data tersebut

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/DiahDSyntia/Data-Mining/main/biopics.csv", encoding = 'unicode_escape', engine ='python')

# %%
data
# Out:
#                      title                                  site country  \
# 0      10 Rillington Place  http://www.imdb.com/title/tt0066730/      UK
# 1         12 Years a Slave  http://www.imdb.com/title/tt2024544/   US/UK
# 2                127 Hours  http://www.imdb.com/title/tt1542344/   US/UK
# 3                     1987  http://www.imdb.com/title/tt2833074/  Canada
# 4                 20 Dates  http://www.imdb.com/title/tt0138987/      US
# ..                     ...                                   ...     ...
# 756  Young Man with a Horn  http://www.imdb.com/title/tt0043153/      US
# 757      Young Mr. Lincoln  http://www.imdb.com/title/tt0032155/      US
# 758       Young Tom Edison  http://www.imdb.com/title/tt0033289/      US
# 759          Young Winston  http://www.imdb.com/title/tt0069528/      US
# 760    Your Cheatin' Heart  http://www.imdb.com/title/tt0058765/      US
#
#      year_release box_office              director  number_of_subjects  \
# ...

# %%
number_of_columns = data.shape[1]

# %%
pd.set_option('display.max_columns', number_of_columns)
pd.set_option('display.max_rows', number_of_columns)

# %%
data.columns
# Out:
# Index(['title', 'site', 'country', 'year_release', 'box_office', 'director',
#        'number_of_subjects', 'subject', 'type_of_subject', 'race_known',
#        'subject_race', 'person_of_color', 'subject_sex', 'lead_actor_actress'],
#       dtype='object')

# %% [markdown]
# ## Categorical/nominal Features
# person_of_color
# subject_sex

# %%
data[["director","person_of_color", "subject_sex"]].head(15)
# Out:
#              director  person_of_color subject_sex
# 0   Richard Fleischer                0        Male
# 1       Steve McQueen                1        Male
# 2         Danny Boyle                0        Male
# 3       Ricardo Trogi                0        Male
# 4     Myles Berkowitz                0        Male
# ..                ...              ...         ...
# 10   David Hugh Jones                0      Female
# 11         Ron Howard                0        Male
# 12   David Cronenberg                0        Male
# 13   David Cronenberg                0        Male
# 14   David Cronenberg                0      Female
#
# [15 rows x 3 columns]

# %% [markdown]
# ## Change Values to 1/0
# ## Take all values of 'person_of_color' and 'subject_sex' series
#
#
# *   if values is
# *   List item
